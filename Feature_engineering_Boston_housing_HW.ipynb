# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import pyplot as plt

# %% [markdown]
# Основные значения:
#
# - CRIM: This is the per capita crime rate by town
# - ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# - INDUS: This is the proportion of non-retail business acres per town.
# - CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# - NOX: This is the nitric oxides concentration (parts per 10 million)
# - RM: This is the average number of rooms per dwelling
# - AGE: This is the proportion of owner-occupied units built prior to 1940
# - DIS: This is the weighted distances to five Boston employment centers
# - RAD: This is the index of accessibility to radial highways
# - TAX: This is the full-value property-tax rate per 10,000 dollars
# - PTRATIO: This is the pupil-teacher ratio by town
# - B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# - LSTAT: This is the percentage lower status of the population
# - MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
from sklearn.datasets import load_boston
import pandas as pd
data = pd.read_csv(load_boston()['filename'], skiprows=1)
data.head(20)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
#Посмотрим распределение по атрибуту CRIM
plt.figure(figsize=(10,5))
sns.kdeplot(data.CRIM)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data.CRIM)

# %%
#Уберем выбросы из выборки
data_2 = data.query('CRIM < 27')

plt.figure(figsize=(10,5))
sns.boxplot(data_2.CRIM)

# %%
#Посмотрим распределение по атрибуту ZN
plt.figure(figsize=(10,5))
sns.kdeplot(data_2.ZN)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data_2.ZN)

# %%
#Уберем выбросы из выборки
data_3 = data_2.query('ZN < 90')

sns.boxplot(data_3.ZN)

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(data_3.ZN)

# %%
data_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 468 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       468 non-null float64
# ZN         468 non-null float64
# INDUS      468 non-null float64
# CHAS       468 non-null int64
# NOX        468 non-null float64
# RM         468 non-null float64
# AGE        468 non-null float64
# DIS        468 non-null float64
# RAD        468 non-null int64
# TAX        468 non-null int64
# PTRATIO    468 non-null float64
# B          468 non-null float64
# LSTAT      468 non-null float64
# MEDV       468 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 54.8 KB

# %%
#Посмотрим распределение по атрибуту INDUS
plt.figure(figsize=(10,5))
sns.kdeplot(data_3.INDUS)

# %%
#Я считаю, что по данным графикам можно заключить, что явных выбросов нет и поэтому предлагаю этот атрибут не трогать
plt.figure(figsize=(10,5))
sns.boxplot(data_3.INDUS)

# %%
#Посмотрим распределение по атрибуту CHAS
sns.countplot(x='CHAS', data=data_3)

# %%
#Думаю количество значений "1" достаточно большое и поэтому с этим атрибутом не будем ничего делать
data_CHAS = data_3.groupby('CHAS').ZN.count()
data_CHAS
# Out:
# CHAS
# 0    453
# 1     34
# Name: ZN, dtype: int64

# %%
#Посмотрим распределение по атрибуту NOX
plt.figure(figsize=(10,5))
sns.kdeplot(data_3.NOX)

# %%
#Есть значения с васоким уровнем NOX, но их достаточно много и поэтому предлагаю также не трогать этот атрибут
plt.figure(figsize=(10,5))
sns.boxplot(data_3.NOX)

# %%
#Посмотрим распределение по атрибуту RM
plt.figure(figsize=(10,5))
sns.distplot(data_3.RM)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data_3.RM)

# %%
#Предлагаю убрать данные где значения RM либо меньше 3, либо больше 8 
data_4 = data_3.query('4 < RM < 8')

# %%
plt.figure(figsize=(10,5))
sns.distplot(data_4.RM)

# %%
#Посмотрим распределение по атрибуту DIS
plt.figure(figsize=(10,5))
sns.boxplot(data_4.DIS)

# %%
#Предлагаю убрать выбросы где значения DIS больше 10 
data_5 = data_4.query('DIS < 10')

# %%
#Посмортрим как распределение выглядит теперь
plt.figure(figsize=(10,5))
sns.boxplot(data_5.DIS)

# %%
#Посмотрим распределение по атрибуту RAD
plt.figure(figsize=(10,5))
data_5['RAD'].hist()

# %%
#Как можем видить нет значений между 8 и 24, но те значения, что есть представлены в достаточно количестве 
# и поэтому думаю с этим атрибутом не нужно делать каких-либо приобразований
data_5['RAD'].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  8,  6,  7, 24])

# %%
#Посмотрим распределение по атрибуту TAX
plt.figure(figsize=(10,5))
sns.distplot(data_5.TAX)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data_5.TAX)

# %%
# Думаю можно заключить, что по данному атрибуту нет явных выбросов и поэтому предлагаю не делать никаких преобразований

# %%
#Посмотрим распределение по атрибуту PTRATIO
plt.figure(figsize=(10,5))
sns.distplot(data_5.PTRATIO)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data_5.PTRATIO)

# %%
#Предлагаю убрать выбросы где значения PTRATIO меньше 14 
data_6 = data_5.query('14 < PTRATIO')

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data_6.PTRATIO)

# %%
#Посмотрим распределение по атрибуту B
plt.figure(figsize=(10,5))
sns.distplot(data_6.B)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data_6.B)

# %%
#Давайте посмотрим как изменится распределение если убрать значения атрибута B меньше чем 150 
data_7 = data_6.query('B > 150')

plt.figure(figsize=(10,5))
sns.boxplot(data_7.B)

# %%
#Наша выблорка сократилась на 31 значение в результате этого преобразования, но все равно еще осталось большое количество выбросов
#Предлогаю оставить данные пока в таком виде
print(len(data_6))
print(len(data_7))
# Out:
# 457
# 426

# %%
#Посмотрим распределение по атрибуту LSTAT
plt.figure(figsize=(10,5))
sns.distplot(data_7.LSTAT)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data_7.LSTAT)

# %%
#Предлагаю убрать выбросы со значением LSTAT больше чем 32
data_8 = data_7.query('LSTAT < 32')

plt.figure(figsize=(10,5))
sns.boxplot(data_8.LSTAT)

# %%
from sklearn.model_selection import train_test_split
train_test_split(data_8, data_8.MEDV, test_size=0.2, random_state=30)
# Out:
# [        CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
#  146  2.15505  0.0  19.58     0  0.871  5.628  100.0  1.5166    5  403
#  207  0.25199  0.0  10.59     0  0.489  5.783   72.7  4.3549    4  277
#  42   0.14150  0.0   6.91     0  0.448  6.169    6.6  5.7209    3  233
#  178  0.06642  0.0   4.05     0  0.510  6.860   74.4  2.9153    5  296
#  339  0.05497  0.0   5.19     0  0.515  5.985   45.4  4.8122    5  224
#  ..       ...  ...    ...   ...    ...    ...    ...     ...  ...  ...
#  490  0.20746  0.0  27.74     0  0.609  5.093   98.0  1.8226    4  711
#  145  2.37934  0.0  19.58     0  0.871  6.130  100.0  1.4191    5  403
#  337  0.03041  0.0   5.19     0  0.515  5.895   59.6  5.6150    5  224
#  504  0.10959  0.0  11.93     0  0.573  6.794   89.3  2.3889    1  273
#  329  0.06724  0.0   3.24     0  0.460  6.333   17.2  5.2146    4  430
#
#       PTRATIO       B  LSTAT  MEDV
#  146     14.7  169.27  16.65  15.6
#  207     18.6  389.43  18.06  22.5
# ...

# %%
import sys
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
import numpy as np

from sklearn.linear_model import LinearRegression

estimator = LinearRegression()
regression_model = GridSearchCV(estimator, grid_params, cv=5, n_jobs=-1, verbose=1)
regression_model.fit(X_train, y_train)
y_pred = regression_model.predict(X_test)
print("R2: \t", r2_score(y_test, y_pred))
print("RMSE: \t", sqrt(mean_squared_error(y_test, y_pred)))
print("MAE: \t", mean_absolute_error(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-d90443dedc97> in <module>
#       8
#       9 estimator = LinearRegression()
# ---> 10 regression_model = GridSearchCV(estimator, grid_params, cv=5, n_jobs=-1, verbose=1)
#      11 regression_model.fit(X_train, y_train)
#      12 y_pred = regression_model.predict(X_test)
#
# NameError: name 'grid_params' is not defined

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
model = LinearRegression()

Direct_Bilirubin = data['Direct_Bilirubin']
Total_Bilirubin = data['Total_Bilirubin']
Direct_Bilirubin = np.array(Direct_Bilirubin).reshape(-1,1)
Total_Bilirubin = np.array(Total_Bilirubin).reshape(-1,1)

X_train, X_test, y_train, y_test = train_test_split(
    Total_Bilirubin,
    Direct_Bilirubin,
    test_size = 0.2)

model.fit(X_train, y_train)
predicted_y = model.predict(X_test)
model.score(X_test, y_test)
